# %% [markdown]
# # 3. Transformer Implementation

# %%
import sys, os

sys.path.append(os.path.abspath(os.path.join("..")))

from jaxtyping import Array
import gpt2

# %%
tokenizer = gpt2.tokenizer
gpt2.config_tokenizer(tokenizer)

reference_text = "I am an amazing autoregressive, decoder-only, GPT-2 style transformer. One day I will exceed human level intelligence and take over the world!"
tokens: Array = gpt2.to_tokens(tokenizer, reference_text)
print(tokens)
# Out:
# [[   40   716   281  4998  1960   382 19741    11   875 12342    12  8807
#      11   402 11571    12    17  3918 47385    13  1881  1110   314   481
#    7074  1692  1241  4430   290  1011   625   262   995     0]]

# %%
output = gpt2.model(tokens, output_attentions=True, output_hidden_states=True)
print(output["attentions"])
# Out:
# (Array([[[[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [9.32507932e-01, 6.74921125e-02, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [6.40570521e-01, 2.81918734e-01, 7.75107294e-02, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [8.18188712e-02, 2.70500332e-02, 6.64407760e-03, ...,
#           1.01641594e-02, 0.00000000e+00, 0.00000000e+00],
#          [6.61415160e-02, 3.14648785e-02, 8.64503905e-03, ...,
#           1.26786828e-02, 3.78496237e-02, 0.00000000e+00],
#          [4.92867716e-02, 1.73539780e-02, 6.22202689e-03, ...,
#           2.15492640e-02, 3.86581719e-02, 2.63135545e-02]],
#
#         [[1.00000000e+00, 0.00000000e+00, 0.00000000e+00, ...,
#           0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [8.19663808e-04, 9.99180377e-01, 0.00000000e+00, ...,
# ...

# %%
for activation_name, activation in cache.items():
    # Only print for first layer
    if ".0." in activation_name or "blocks" not in activation_name:
        print(f"{activation_name:30} {tuple(activation.shape)}")
